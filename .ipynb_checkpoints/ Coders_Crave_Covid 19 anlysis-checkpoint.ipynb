# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv("country_wise_latest.csv")

# %%
data
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
data.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
data.tail()
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 182           2              0                0.73                  35.33
# 183           0              0               10.00                  80.00
# 184           4             36               28.56                  49.26
# 185           1            465                3.08                  61.84
# 186           2             24                1.33                  20.04
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    int64
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New cases               187 non-null    int64
#  6   New deaths              187 non-null    int64
#  7   New recovered           187 non-null    int64
#  8   Deaths / 100 Cases      187 non-null    float64
#  9   Recovered / 100 Cases   187 non-null    float64
#  10  Deaths / 100 Recovered  187 non-null    float64
#  11  Confirmed last week     187 non-null    int64
#  12  1 week change           187 non-null    int64
#  13  1 week % increase       187 non-null    float64
# ...

# %%
data.shape
# Out:
# (187, 15)

# %%
data.describe()
# Out:
#           Confirmed         Deaths     Recovered        Active     New cases  \
# count  1.870000e+02     187.000000  1.870000e+02  1.870000e+02    187.000000
# mean   8.813094e+04    3497.518717  5.063148e+04  3.400194e+04   1222.957219
# std    3.833187e+05   14100.002482  1.901882e+05  2.133262e+05   5710.374790
# min    1.000000e+01       0.000000  0.000000e+00  0.000000e+00      0.000000
# 25%    1.114000e+03      18.500000  6.265000e+02  1.415000e+02      4.000000
# 50%    5.059000e+03     108.000000  2.815000e+03  1.600000e+03     49.000000
# 75%    4.046050e+04     734.000000  2.260600e+04  9.149000e+03    419.500000
# max    4.290259e+06  148011.000000  1.846641e+06  2.816444e+06  56336.000000
#
#         New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# count   187.000000     187.000000          187.000000             187.000000
# mean     28.957219     933.812834            3.019519              64.820535
# ...

# %%
data.isnull().sum()
# Out:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
correlation =data.corr()

# %%
## creating the heatmap
sns.heatmap(correlation,cmap='plasma',center=0,annot=True)
# Out:
# <AxesSubplot:>

# %%
data=data.dropna()
print(data)
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,8))
sns.barplot(data=data[:20], x="Country/Region", y="Deaths")

plt.ylabel("Deaths")
# Out:
# Text(0, 0.5, 'Deaths')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,8))
sns.barplot(data=data[:20], x="Country/Region", y="Active")

plt.ylabel("Active")
# Out:
# Text(0, 0.5, 'Active')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,8))
sns.barplot(data=data[:20], x="Country/Region", y="Confirmed")
plt.ylabel("Confirmed")
# Out:
# Text(0, 0.5, 'Confirmed')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,8))
sns.barplot(data=data[:20], x="Country/Region", y="Recovered")

plt.ylabel("Recovered")
# Out:
# Text(0, 0.5, 'Recovered')

# %%
top_countries=data.groupby('Country/Region')['Confirmed'].max().nlargest(10)

# %%
top_countries.plot(kind='barh')
plt.title('Top10 Countries with the Highest Number of Covid-19 Cases')
plt.xlabel('Total Cases')
plt.ylabel('Country')
plt.show()

# %%
def build_graph(y_label):
    import matplotlib.pyplot as plt
    plt.figure(figsize=(20,8))
    return sns.barplot(x="Country/Region", y=y_label, data=data[:20])

# %%
data["Deaths"] = (data["Deaths"]/data["Confirmed"])*100
data["Recovered"] = (data["Recovered"]/data["Confirmed"])*100
data['Active']=(data['Active']/data['Confirmed'])*100

# %%
build_graph("Deaths")
# Out:
# <AxesSubplot:xlabel='Country/Region', ylabel='Deaths'>

# %%
build_graph("Recovered")
# Out:
# <AxesSubplot:xlabel='Country/Region', ylabel='Recovered'>

# %%
build_graph('Active')
# Out:
# <AxesSubplot:xlabel='Country/Region', ylabel='Active'>

# %%
total_by_country=data.groupby('Country/Region')['Confirmed','Deaths','Recovered'].max()
# Out:
# C:\Users\nikhi\AppData\Local\Temp\ipykernel_13436\447282357.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   total_by_country=data.groupby('Country/Region')['Confirmed','Deaths','Recovered'].max()

# %%
total_by_country
# Out:
#                     Confirmed     Deaths  Recovered
# Country/Region
# Afghanistan             36263   3.499435  69.486805
# Albania                  4880   2.950820  56.250000
# Algeria                 27973   4.157581  67.339935
# Andorra                   907   5.733186  88.533627
# Angola                    950   4.315789  25.473684
# ...                       ...        ...        ...
# West Bank and Gaza      10621   0.734394  35.326240
# Western Sahara             10  10.000000  80.000000
# Yemen                    1691  28.562980  49.260792
# Zambia                   4552   3.075571  61.840949
# Zimbabwe                 2704   1.331361  20.044379
#
# [187 rows x 3 columns]

# %%
total_by_country['Recovery Rate']=total_by_country['Recovered']/total_by_country['Confirmed']*100

# %%
total_by_country
# Out:
#                     Confirmed     Deaths  Recovered  Recovery Rate
# Country/Region
# Afghanistan             36263   3.499435  69.486805       0.191619
# Albania                  4880   2.950820  56.250000       1.152664
# Algeria                 27973   4.157581  67.339935       0.240732
# Andorra                   907   5.733186  88.533627       9.761150
# Angola                    950   4.315789  25.473684       2.681440
# ...                       ...        ...        ...            ...
# West Bank and Gaza      10621   0.734394  35.326240       0.332607
# Western Sahara             10  10.000000  80.000000     800.000000
# Yemen                    1691  28.562980  49.260792       2.913116
# Zambia                   4552   3.075571  61.840949       1.358545
# Zimbabwe                 2704   1.331361  20.044379       0.741286
#
# [187 rows x 4 columns]

# %%
total_by_country['Recovery Rate']=total_by_country['Deaths']/total_by_country['Confirmed']*100

# %%
total_by_country
# Out:
#                     Confirmed     Deaths  Recovered  Recovery Rate
# Country/Region
# Afghanistan             36263   3.499435  69.486805       0.009650
# Albania                  4880   2.950820  56.250000       0.060468
# Algeria                 27973   4.157581  67.339935       0.014863
# Andorra                   907   5.733186  88.533627       0.632104
# Angola                    950   4.315789  25.473684       0.454294
# ...                       ...        ...        ...            ...
# West Bank and Gaza      10621   0.734394  35.326240       0.006915
# Western Sahara             10  10.000000  80.000000     100.000000
# Yemen                    1691  28.562980  49.260792       1.689118
# Zambia                   4552   3.075571  61.840949       0.067565
# Zimbabwe                 2704   1.331361  20.044379       0.049237
#
# [187 rows x 4 columns]
